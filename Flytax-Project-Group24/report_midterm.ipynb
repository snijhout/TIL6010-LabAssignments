# %% [markdown]
# # Project Group -
#
# Members: \
# Duncan Sieval (6091326)\
# Karlijn Jansen (5106192) \
# Nathalie Budel (5412560)\
# Sandrine Nijhout (5374006)\
# Maritte de Ruiter (5364817)

# %% [markdown]
# # Introduction
# The flight tax will be increased with €2,62 for departing passengers from the Netherlands as of January 1, 2024 (Welk Bedrag Betaal Ik Aan Vliegbelasting?, z.d.).
# After this increase, the new rate including indexation and increase comes to € 29,05 per departing passenger (Belastingdienst, 2024). This study will examine the impact of this increase on the number of departing flights and passengers. Finally, the influence of the air passenger tax on CO2 emissions will be examined.

# %% [markdown]
# # Research Objective
# ## How does the implementation of the fly tax affect CO2 emissions from commercial flights in the Netherlands?

# %% [markdown]
# ##### Sub-Questions
#
# #### 1. How has the flight tax influenced the number of flights to and from the Netherlands?
# #### 2. How has the flight tax impacted passenger demand for flights to and from the Netherlands and does this impact differ for intercontinental and european flights?
#
# #### 3. To what extent will the flight tax contribute to reducing CO2 emissions for different flights to and from the Netherlands?

# %% [markdown]
# # 1. Analyses on flight tax influence on the number of flights
# To examine the impact of the flight tax on the number of flights in the Netherlands, we will first look at the number of flights between 2000 and 2024. The table below shows how these flights changed over the past 24 years. The chart graphically shows the change in the number of flights departing from the Netherlands.

# %% [markdown]
# - nog weinig verandering te zien  (te korte periode)
# - in toekomst verwachten we wel verandering, waarom? lijn vluchten nog herstellende van corona. dus goed verschil te kunnen zien wil je cijfers van hersteld gedrag zien. onze aanname was dat het al hersteld zou zijn in twee jaar.
# - groei waardes staan in updated_luchtvaard_growth.csv, hiervan moet tabel nog erin komen. uitleg hierover
#
# - uitleggen zoals hieronder al gedaan waar averages van gekozen zijn (uitleg 2e kwartaal van alles)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It then looks at the annual increase over these past 24 years. This is reflected in the table below. Corona, as seen in the chart above, had a big impact between 2020 and 2022. Therefore, these years are not included in the calculation. An average is taken for the years between 2000 and 2020. This average is then compared to the annual increase after the flight tax is implemented between 2023 and 2024.

# %% [markdown]
# # 2. Analyses on flight tax influence on passenger demand and difference between intercontinental and european flights

# %% [markdown]
# After looking at the number of flights changed by the flight tax. Sub-question 2 will look at the number of passengers affected by the flight tax. This will distinguish between European and continental flights. The amount of the flight tax for both flights is the same, but it can have a different impact. The graph below shows the number of passengers departing from the Netherlands to a European or intercontinental destination.

# %% [markdown]
# - nog weinig verandering te zien  (te korte periode)
# - in toekomst verwachten we wel verandering, waarom? lijn vluchten nog herstellende van corona. dus goed verschil te kunnen zien wil je cijfers van hersteld gedrag zien. onze aanname was dat het al hersteld zou zijn in twee jaar.
# - groei waardes staan in updated_luchtvaard_growth.csv, hiervan moet tabel nog erin komen. uitleg hierover
#
# - uitleggen zoals hieronder al gedaan waar averages van gekozen zijn (uitleg 2e kwartaal van alles)
# - concl is dat niet uit maakt of je naar vluchten of passagiers kijkt
# - intercontinentaal na corona minder geworden , maar niks met tax te maken
# - verwacht  dat impact op intercontinentaal kleiner zou zijn (3eu op 1000 is bijv minder effect dan 3eu op 100) , maar niet te zien .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then this study looked at how the annual growth from 2000 to 2020 (years before corona came) compares with the increase in travelers between 2023 and 2024, because in this year the flight tax was introduced.

# %% [markdown]
# # 3. Which flights produce the most CO2 emissions, and which of these flights would you seek to restrict with a flight tax?

# %% [markdown]
# Note: running this code will take 10 minutes.
#
# - lange, korte en middellange vluchten
# - welke hebben meeste uitstoot
# - je kan beoordelen op afstand maar ook op hoeveelheid passagiers
# - mogelijkheid verschuiven naar ander vervoersmiddel
# - runnen code duurt 10 minuten , dus dat als comment vermelden

# %% [markdown]
# ![image.png](attachment:image.png)
# Figure ...:
# ![image-3.png](attachment:image-3.png)
# Figure ...:

# %% [markdown]
# # Contribution Statement
#
# *Be specific. Some of the tasks can be coding (expect everyone to do this), background research, conceptualisation, visualisation, data analysis, data modelling*

# %% [markdown]
# **Author 1**:
#
# **Author 2**:
#
# **Author 3**:

# %% [markdown]
# # Data Used

# %% [markdown]
# # Data Pipeline

# %% [markdown]
# - Welk bedrag betaal ik aan vliegbelasting? (z.d.). Transavia. https://www.transavia.com/service/nl-nl/zoeken-en-boeken/vliegbelasting/hoeveel-vliegbelasting#
# - Belastingdienst. (2024, 28 juni). Vliegbelasting. https://www.belastingdienst.nl/wps/wcm/connect/bldcontentnl/belastingdienst/zakelijk/overige_belastingen/belastingen_op_milieugrondslag/vliegbelasting/
